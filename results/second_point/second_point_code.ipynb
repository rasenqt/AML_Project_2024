# %%
# !git clone https://github.com/ranahanocka/point2mesh.git
# %cd point2mesh

# %%
# !wget https://www.dropbox.com/s/nn9hsww6mr0zccm/data.tar
# !tar -xvf data.tar && rm data.tar

# %%
import sys
import torch
pyt_version_str=torch.__version__.split("+")[0].replace(".", "")
version_str="".join([
    f"py3{sys.version_info.minor}_cu",
    torch.version.cuda.replace(".",""),
    f"_pyt{pyt_version_str}"
])
# !pip install fvcore iopath
# !pip install --no-index --no-cache-dir pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/{version_str}/download.html

# %%
# !python main.py --input-pc ./data/giraffe.ply \
--initial-mesh ./data/giraffe_initmesh.obj \
--save-path ./checkpoints/giraffe \
--iterations 1000 # regola in base al livello di dettaglio che vuoi raggiungere -> più iterazioni, più preciso, ma se ci sono pochi punti è ok andare bene anche con 1000 iterazioni
